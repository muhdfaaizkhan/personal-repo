# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 5px; height: 70px">
#
# # Optimising Hospital Bed Occupancy through Machine Learning
# **DSI-41 Group FWSG**: Muhammad Faaiz Khan, Sharifah Nurulhuda, Tan Wei Chiong, Gabriel Tan

# %% [markdown]
# ### 03. Modelling: SARIMAX

# %% [markdown]
# ### Overview

# %% [markdown]
# The model in this section uses SARIMAX, with rainfall data, wet bulb temperature, the `is_holiday` binary variable, and infectious disease data as exogeneous features.
#
# A significant difference between this section and most of the other sections is that only data from 2022 onwards is used, as 2022 is when the COVID-19 in Singapore started to be seen as endemic. This allows us to see what the predictions would be like in a post-COVID Singapore.
#
# Here is a brief description of the model used:
#
# |Model|What it is|What is it used for|
# |---|---|---|
# |SARIMAX|Seasonal Auto-Regressive Integrated Moving Average with eXogeneous features|Predicting future points in a time series, with exogeneous predictors|

# %% [markdown]
# ### Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_absolute_percentage_error
from sklearn.compose import ColumnTransformer 
import pmdarima as pm

# %% [markdown]
# ### Preparing Data for Modelling

# %%
final_df = pd.read_csv('../datasets/for_timeseries.csv')

# %%
final_df.head()
# Out:
#          date  year   nuh  total_rainfall  wet_bulb_temperature  dengue  \
# 0  2022-01-01  2022  72.0            25.2                  26.0    11.0
# 1  2022-01-02  2022  73.7            50.0                  24.1    15.0
# 2  2022-01-03  2022  78.7             6.0                  25.6    15.0
# 3  2022-01-04  2022  79.1             4.8                  25.8    15.0
# 4  2022-01-05  2022  81.8             1.0                  26.3    15.0
#
#     urti  diarrhea  is_holiday  day_Mon  ...  month_Dec  month_Feb  month_Jan  \
# 0  904.0     287.0           1    False  ...      False      False       True
# 1  977.0     297.0           0    False  ...      False      False       True
# 2  977.0     297.0           0     True  ...      False      False       True
# 3  977.0     297.0           0    False  ...      False      False       True
# 4  977.0     297.0           0    False  ...      False      False       True
#
#    month_Jul  month_Jun  month_Mar  month_May  month_Nov  month_Oct  month_Sep
# 0      False      False      False      False      False      False      False
# 1      False      False      False      False      False      False      False
# 2      False      False      False      False      False      False      False
# 3      False      False      False      False      False      False      False
# 4      False      False      False      False      False      False      False
#
# [5 rows x 26 columns]

# %%
final_df['date'] = pd.to_datetime(final_df['date'])
final_df = final_df[final_df['date'] >= dt.datetime(2022,1,1)].copy()
for col in ['year']:
    final_df[col] = [str(num) for num in final_df[col].values.tolist()]
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 730 entries, 0 to 729
# Data columns (total 26 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   date                  730 non-null    datetime64[ns]
#  1   year                  730 non-null    object
#  2   nuh                   730 non-null    float64
#  3   total_rainfall        730 non-null    float64
#  4   wet_bulb_temperature  730 non-null    float64
#  5   dengue                730 non-null    float64
#  6   urti                  730 non-null    float64
#  7   diarrhea              730 non-null    float64
#  8   is_holiday            730 non-null    int64
#  9   day_Mon               730 non-null    bool
#  10  day_Sat               730 non-null    bool
#  11  day_Sun               730 non-null    bool
#  12  day_Thu               730 non-null    bool
#  13  day_Tue               730 non-null    bool
#  14  day_Wed               730 non-null    bool
#  15  month_Aug             730 non-null    bool
#  16  month_Dec             730 non-null    bool
#  17  month_Feb             730 non-null    bool
#  18  month_Jan             730 non-null    bool
#  19  month_Jul             730 non-null    bool
#  20  month_Jun             730 non-null    bool
#  21  month_Mar             730 non-null    bool
#  22  month_May             730 non-null    bool
#  23  month_Nov             730 non-null    bool
#  24  month_Oct             730 non-null    bool
#  25  month_Sep             730 non-null    bool
# dtypes: bool(17), datetime64[ns](1), float64(6), int64(1), object(1)
# memory usage: 63.6+ KB

# %%
final_df.head()
# Out:
#         date  year   nuh  total_rainfall  wet_bulb_temperature  dengue   urti  \
# 0 2022-01-01  2022  72.0            25.2                  26.0    11.0  904.0
# 1 2022-01-02  2022  73.7            50.0                  24.1    15.0  977.0
# 2 2022-01-03  2022  78.7             6.0                  25.6    15.0  977.0
# 3 2022-01-04  2022  79.1             4.8                  25.8    15.0  977.0
# 4 2022-01-05  2022  81.8             1.0                  26.3    15.0  977.0
#
#    diarrhea  is_holiday  day_Mon  ...  month_Dec  month_Feb  month_Jan  \
# 0     287.0           1    False  ...      False      False       True
# 1     297.0           0    False  ...      False      False       True
# 2     297.0           0     True  ...      False      False       True
# 3     297.0           0    False  ...      False      False       True
# 4     297.0           0    False  ...      False      False       True
#
#    month_Jul  month_Jun  month_Mar  month_May  month_Nov  month_Oct  month_Sep
# 0      False      False      False      False      False      False      False
# 1      False      False      False      False      False      False      False
# 2      False      False      False      False      False      False      False
# 3      False      False      False      False      False      False      False
# 4      False      False      False      False      False      False      False
#
# [5 rows x 26 columns]

# %% [markdown]
# Lastly, we set the `date` column as index for use in SARIMAX.

# %%
final_df.set_index('date', inplace=True)

# %% [markdown]
# ### Pipeline creation

# %%
# defining specific subsets of features
time_features = ['year', 'month', 'day_of_week']
event_features = ['is_holiday']
hospital_features = ['nuh']
weather_features = ['total_rainfall', 'wet_bulb_temperature']
disease_features = ['dengue', 'urti', 'diarrhea']

# %%
# defining the train-test split and training the pipeline

def hospital_pipe(hospital):
    '''Returns the fitted SARIMAX model with `hospital` as the target variable, along with the respective train-test splits
    '''

    # remaining_hospitals = [hosp for hosp in hospital_features if hosp != hospital]

    X = final_df[weather_features + event_features + disease_features]
    y = final_df[hospital]

    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)

    # defining pipelines
    preprocessor = ColumnTransformer(
        transformers = [
            ('weather_numeric', StandardScaler(), weather_features + disease_features)
        ],
        remainder = 'passthrough'
    )

    # preprocesses the X train-test variables
    pp_X_train = preprocessor.fit_transform(X_train)
    pp_X_test = preprocessor.transform(X_test)

    # defines a new sarimax pipeline
    # this is needed because we're fitting a pipeline for each hospital
    sarimax_model = pm.AutoARIMA(start_p=1, max_p=10, 
                                 d=1,          # find optimum value of d automatically
                                 start_q=1, max_q=10,
                                 start_P=0, max_P=10,
                                 D=None,
                                 start_Q=0, max_Q=10,
                                 m=7,          # data repeats every 7 days
                                 seasonal=True,
                                 trace=True,   # Print values for each fit in the grid search
                                 random_state=42,
                                 maxiter=10
                                )

    # fits a SARIMAX model on the respective hospital
    sarimax_model.fit(y_train, pp_X_train)

    # returns the respective train-test split and the fitted SARIMAX pipe
    return (pp_X_train, pp_X_test, y_train, y_test, sarimax_model)

# %% [markdown]
# Now we fit each model and store it in a lookup table.

# %%
hospital_pipes = {hospital: hospital_pipe(hospital) for hospital in hospital_features}
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(0,0,0)[7] intercept   : AIC=2680.345, Time=0.11 sec
#  ARIMA(0,1,0)(0,0,0)[7] intercept   : AIC=2732.651, Time=0.06 sec
#  ARIMA(1,1,0)(1,0,0)[7] intercept   : AIC=2574.954, Time=0.16 sec
#  ARIMA(0,1,1)(0,0,1)[7] intercept   : AIC=2638.202, Time=0.16 sec
#  ARIMA(0,1,0)(0,0,0)[7]             : AIC=2730.714, Time=0.08 sec
#  ARIMA(1,1,0)(0,0,0)[7] intercept   : AIC=2730.493, Time=0.07 sec
#  ARIMA(1,1,0)(2,0,0)[7] intercept   : AIC=2523.089, Time=0.33 sec
#  ARIMA(1,1,0)(3,0,0)[7] intercept   : AIC=2486.714, Time=0.76 sec
#  ARIMA(1,1,0)(4,0,0)[7] intercept   : AIC=2447.256, Time=1.37 sec
#  ARIMA(1,1,0)(5,0,0)[7] intercept   : AIC=inf, Time=2.70 sec
#  ARIMA(1,1,0)(4,0,1)[7] intercept   : AIC=2432.963, Time=1.54 sec
#  ARIMA(1,1,0)(3,0,1)[7] intercept   : AIC=2430.156, Time=0.82 sec
#  ARIMA(1,1,0)(2,0,1)[7] intercept   : AIC=2429.555, Time=0.39 sec
#  ARIMA(1,1,0)(1,0,1)[7] intercept   : AIC=2420.904, Time=0.19 sec
#  ARIMA(1,1,0)(0,0,1)[7] intercept   : AIC=2638.224, Time=0.15 sec
#  ARIMA(1,1,0)(1,0,2)[7] intercept   : AIC=2423.987, Time=0.37 sec
#  ARIMA(1,1,0)(0,0,2)[7] intercept   : AIC=2600.238, Time=0.34 sec
#  ARIMA(1,1,0)(2,0,2)[7] intercept   : AIC=2413.910, Time=0.42 sec
#  ARIMA(1,1,0)(3,0,2)[7] intercept   : AIC=2417.758, Time=0.96 sec
#  ARIMA(1,1,0)(2,0,3)[7] intercept   : AIC=2412.993, Time=0.88 sec
#  ARIMA(1,1,0)(1,0,3)[7] intercept   : AIC=2427.633, Time=0.76 sec
#  ARIMA(1,1,0)(3,0,3)[7] intercept   : AIC=inf, Time=0.98 sec
#  ARIMA(1,1,0)(2,0,4)[7] intercept   : AIC=inf, Time=1.91 sec
#  ARIMA(1,1,0)(1,0,4)[7] intercept   : AIC=2432.180, Time=1.40 sec
#  ARIMA(1,1,0)(3,0,4)[7] intercept   : AIC=inf, Time=1.97 sec
#  ARIMA(0,1,0)(2,0,3)[7] intercept   : AIC=inf, Time=0.98 sec
#  ARIMA(2,1,0)(2,0,3)[7] intercept   : AIC=2419.553, Time=0.95 sec
#  ARIMA(1,1,1)(2,0,3)[7] intercept   : AIC=2436.428, Time=0.96 sec
#  ARIMA(0,1,1)(2,0,3)[7] intercept   : AIC=2418.691, Time=0.95 sec
#  ARIMA(2,1,1)(2,0,3)[7] intercept   : AIC=2462.379, Time=1.18 sec
#  ARIMA(1,1,0)(2,0,3)[7]             : AIC=inf, Time=0.77 sec
#
# Best model:  ARIMA(1,1,0)(2,0,3)[7] intercept
# Total fit time: 24.720 seconds

# %%
hospital_pipes
# Out:
# {'nuh': (array([[ 1.35714446, -0.16801495, -0.9579199 , -2.72735372, -1.82516296,
#            1.        ],
#          [ 3.15920494, -2.70102297, -0.88625843, -2.5914095 , -1.5667328 ,
#            0.        ],
#          [-0.03799915, -0.7012798 , -0.88625843, -2.5914095 , -1.5667328 ,
#            0.        ],
#          ...,
#          [-0.47398153,  1.03183095, -0.7429355 ,  0.20010254, -0.06783792,
#            0.        ],
#          [-0.47398153, -0.43464737, -0.65335867,  0.14795955,  0.81082461,
#            0.        ],
#          [-0.47398153,  0.09861747, -0
#   2023-08-05    83.4
#   2023-08-06    85.7
#   2023-08-07    89.2
#   Name: nuh, Length: 584, dtype: float64,
#   date
#   2023-08-08    87.0
#   2023-08-09    87.6
#   2023-08-10    87.5
#   2023-08-11    85.3
#   2023-08-12    81.9
#                 ...
#   2023-12-27    85.2
#   2023-12-28    87.4
#   2023-12-29    84.1
#   2023-12-30    79.4
#   2023-12-31    78.0
#   Name: nuh, Length: 146, dtype: float64,
#   AutoARIMA(d=1, m=7, max_P=10, max_Q=10, max_p=10, max_q=10, maxiter=10,
#             random_state=42, start_P=0, start_Q=0, start_p=1, start_q=1,
#             trace=True))}

# %%
# Create helper function to help make predictions and plot the results 
# function captures the same steps as previous lesson with just the addition of `X_test` to use for SARIMAX model next

def plot_forecast(y_train, y_test, arima_model, X_test=None):
    # Generate len(y_test) number of predictions
    y_pred = arima_model.predict(n_periods = len(y_test), X=X_test) # we want as many future data point predictions as there are in y_test

    # Plot data.
    plt.figure(figsize=(30,15))

    # Plot training data. don't need to explicitly pass x-axis for chart, taken as the date index by matplotlib
    plt.plot(y_train, color='blue', label='y_train')

    # Plot testing data. don't need to explicitly pass x-axis for chart, taken as the date index by matplotlib
    plt.plot(y_test, color='orange', label='y_test', alpha = 0.7)

    # Plot predicted test values. as shared previously, there are no index in y_pred 
    # so, we need to explicitly pass the `x-axis` (dates) to compare for same timeframe as y_test and access y_pred vs actual y_test
    # we can use y_test.index to get the index of y_test as confirmed earlier in y_test.head()
    plt.plot(y_pred, color='green', label='y_pred', alpha = 0.9, ls = '--')
    
    # Find the MAPE (mean abs percentage error) of the predictions
    # https://scikit-learn.org/stable/modules/generated/sklearn.metrics.mean_absolute_percentage_error.html
    mape = mean_absolute_percentage_error(y_test, y_pred) # like all sklearn metrics we've used, pass y_actual, y_pred

    plt.title(label = f'Bed Occupancy Rate Predictions\n MAPE: {mape:.2f}', fontsize=16) #\n is just for new line to print MAPE 1 line after header 'Bed Occupancy Rate Predictions', while .2f rounds MAPE to 2 decimals
    plt.legend(fontsize = 20, loc = 'upper left'); # for legend to be displayed in our plot

    return mape

# %%
for hospital in hospital_features:
    mape = plot_forecast(hospital_pipes[hospital][2], # y_train
                         hospital_pipes[hospital][3], # y_test
                         hospital_pipes[hospital][4], # sarimax model
                         hospital_pipes[hospital][1]  # X_test
                        )
    plt.title(label = f'{hospital.upper()} Bed Occupancy Rate Predictions (SARIMAX)\n MAPE: {mape:.2f}', fontsize=16)

# %% [markdown]
# ### Insights
# - Fits and looks almost identical to the model obtained by SARIMA
# - Cannot make predictions outside of test set because of lack of $X$ for those
# times
# - Downsides to this approach: Errors propagate very quickly
# - It seems like exogenous features are not too predictive in this context
# - Model hyperparameters are `ARIMA(1,1,0)(2,0,3)[7]` with intercept
# - Future work: Use SARIMA to individually predict each one of the $X$ features
# past the test set, and then use those predicted $X$ values as $X$ input to SARIMAX
